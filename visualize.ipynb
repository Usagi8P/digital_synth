# %%
import seaborn as sns
import math
import numpy as np
from synth import get_sin_oscilator, normalize, get_squ_oscilator, get_saw_oscilator, get_inverse_saw_oscilator

# %%
c4_oscilator = get_sin_oscilator(261.6255, sample_rate=44_100)
e4_oscilator = get_sin_oscilator(329.63, sample_rate=44_100)
g4_oscilator = get_sin_oscilator(392.00, sample_rate=44_100)

# %%
c4_samples = np.array([next(c4_oscilator) for _ in range(2560)])
e4_samples = np.array([next(e4_oscilator) for _ in range(2560)])
g4_samples = np.array([next(g4_oscilator) for _ in range(2560)])

# %%
data = c4_samples

# %%
sns.lineplot(data=data)
# Out:
# <Axes: >

# %%
data = normalize(c4_samples,e4_samples,g4_samples)

# %%
sns.lineplot(data=data)
# Out:
# <Axes: >

# %%
c4_oscilator = get_sin_oscilator(261.6255, sample_rate=44_100)
c4_squ = get_squ_oscilator(c4_oscilator)

# %%
c4_samples = np.array([next(c4_squ) for _ in range(2560)])

# %%
data = c4_samples

# %%
sns.lineplot(data=data)
# Out:
# <Axes: >

# %%
saw = get_saw_oscilator(1, sample_rate=256)
sin = get_sin_oscilator(1, sample_rate=256)
inv_saw = get_inverse_saw_oscilator(1, sample_rate=256)
sin_samples = np.array([next(sin) for _ in range(256)])
saw_samples = np.array([next(saw) for _ in range(256)])
inv_samples = np.array([next(inv_saw) for _ in range(256)])

# %%
sns.lineplot(data=[sin_samples,saw_samples,inv_samples])
# Out:
# <Axes: >

# %%
saw = get_saw_oscilator(261.6255, sample_rate=44_100)
sin = get_sin_oscilator(261.6255, sample_rate=44_100)
inv_saw = get_inverse_saw_oscilator(261.6255, sample_rate=44_100)
sin_samples = np.array([next(sin) for _ in range(256)])
saw_samples = np.array([next(saw) for _ in range(256)])
inv_saw_samples = np.array([next(inv_saw) for _ in range(256)])

# %%
sns.lineplot(data=[sin_samples,saw_samples,inv_saw_samples])
# Out:
# <Axes: >

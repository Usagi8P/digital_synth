# %%
import seaborn as sns
import math
import numpy as np
from synth import get_sin_oscillator, normalize, get_squ_oscilator

# %%
c4_oscilator = get_sin_oscillator(261.6255, sample_rate=44_100)
e4_oscilator = get_sin_oscillator(329.63, sample_rate=44_100)
g4_oscilator = get_sin_oscillator(392.00, sample_rate=44_100)

# %%
c4_samples = np.array([next(c4_oscilator) for _ in range(2560)])
e4_samples = np.array([next(e4_oscilator) for _ in range(2560)])
g4_samples = np.array([next(g4_oscilator) for _ in range(2560)])

# %%
data = c4_samples+e4_samples+g4_samples

# %%
sns.lineplot(data=data)
# Out:
# <Axes: >

# %%
data = normalize(c4_samples,e4_samples,g4_samples)

# %%
sns.lineplot(data=data)
# Out:
# <Axes: >

# %%
c4_oscilator = get_sin_oscillator(261.6255, sample_rate=44_100)
c4_squ = get_squ_oscilator(c4_oscilator)

# %%
c4_samples = np.array([next(c4_squ) for _ in range(2560)])

# %%
data = c4_samples

# %%
sns.lineplot(data=data)
# Out:
# <Axes: >
